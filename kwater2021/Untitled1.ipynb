# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("data/대기오염시도별실시간평균정보_2020년_05월.csv")
df.columns = ["기간","측정항목","데이터 구분","서울","부산","대구","인천","광주","울산","대전","경기","강원","충북","충남","전북","전남","경북","경남","제주","세종"]
df.head()
# Out:
#            기간 측정항목 데이터 구분     서울     부산     대구     인천     광주     울산     대전  \
# 0  2020-07-08  SO2    일평균  0.003  0.003  0.002  0.003  0.002  0.003  0.005
# 1  2020-07-07  SO2    일평균  0.002  0.003  0.002  0.003  0.002  0.002  0.006
# 2  2020-07-06  SO2    일평균  0.003  0.003  0.002  0.003  0.004  0.002  0.005
# 3  2020-07-05  SO2    일평균  0.003  0.004  0.002  0.003  0.005  0.002  0.006
# 4  2020-07-04  SO2    일평균  0.003  0.003  0.002  0.003  0.003  0.002  0.004
#
#       경기     강원     충북     충남     전북     전남     경북     경남     제주     세종
# 0  0.003  0.002  0.003  0.003  0.003  0.003  0.003  0.003  0.001  0.003
# 1  0.003  0.002  0.003  0.003  0.003  0.003  0.003  0.003  0.001  0.002
# 2  0.003  0.002  0.003  0.003  0.003  0.003  0.004  0.003  0.002  0.002
# 3  0.003  0.002  0.003  0.003  0.003  0.003  0.004  0.003  0.002  0.002
# 4  0.003  0.002  0.003  0.003  0.003  0.003  0.003  0.002  0.001  0.002

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 20 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   기간      180 non-null    object
#  1   측정항목    180 non-null    object
#  2   데이터 구분  180 non-null    object
#  3   서울      180 non-null    float64
#  4   부산      180 non-null    float64
#  5   대구      180 non-null    float64
#  6   인천      180 non-null    float64
#  7   광주      180 non-null    float64
#  8   울산      180 non-null    float64
#  9   대전      180 non-null    float64
#  10  경기      180 non-null    float64
#  11  강원      180 non-null    float64
#  12  충북      180 non-null    float64
#  13  충남      180 non-null    float64
#  14  전북      180 non-null    float64
#  15  전남      180 non-null    float64
#  16  경북      180 non-null    float64
#  17  경남      180 non-null    float64
#  18  제주      180 non-null    float64
#  19  세종      180 non-null    float64
# dtypes: float64(17), object(3)
# ...

# %%
df = df.sort_values(['기간'])
df
# Out:
#              기간   측정항목 데이터 구분      서울      부산      대구      인천      광주      울산  \
# 89   2020-06-09     O3    일평균   0.044   0.038   0.062   0.044   0.042   0.064
# 150  2020-06-09   PM10    일평균  48.000  37.000  57.000  49.000  42.000  63.000
# 120  2020-06-09    NO2    일평균   0.025   0.027   0.015   0.024   0.011   0.020
# 59   2020-06-09     CO    일평균   0.400   0.400   0.400   0.400   0.300   0.500
# 29   2020-06-09    SO2    일평균   0.003   0.005   0.003   0.004   0.003   0.003
# ..          ...    ...    ...     ...     ...     ...     ...     ...     ...
# 90   2020-07-08    NO2    일평균   0.019   0.015   0.012   0.014   0.010   0.012
# 121  2020-07-08   PM10    일평균  32.000  31.000  36.000  26.000  22.000  28.000
# 151  2020-07-08  PM2.5    일평균  20.000  21.000  25.000  15.000  12.000  16.000
# 60   2020-07-08     O3    일평균   0.040   0.047   0.059   0.039   0.034   0.040
# 0    2020-07-08    SO2    일평균   0.003   0.003   0.002   0.003   0.002   0.003
#
# ...

# %%
df = df.drop(["데이터 구분","부산","대구","광주","울산","대전","강원","충북","충남","전북","전남","경북","경남","제주","세종"], axis = 1)
df
# Out:
#              기간   측정항목      서울      인천      경기
# 89   2020-06-09     O3   0.044   0.044   0.050
# 150  2020-06-09   PM10  48.000  49.000  58.000
# 120  2020-06-09    NO2   0.025   0.024   0.023
# 59   2020-06-09     CO   0.400   0.400   0.400
# 29   2020-06-09    SO2   0.003   0.004   0.003
# ..          ...    ...     ...     ...     ...
# 90   2020-07-08    NO2   0.019   0.014   0.014
# 121  2020-07-08   PM10  32.000  26.000  33.000
# 151  2020-07-08  PM2.5  20.000  15.000  20.000
# 60   2020-07-08     O3   0.040   0.039   0.042
# 0    2020-07-08    SO2   0.003   0.003   0.003
#
# [180 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['기간', '측정항목', '서울', '인천', '경기'], dtype='object')

# %%
df=df.loc[[135,136,137,165,166,167]]
df
# Out:
#              기간   측정항목    서울    인천    경기
# 135  2020-06-24   PM10  28.0  27.0  31.0
# 136  2020-06-23   PM10  42.0  33.0  50.0
# 137  2020-06-22   PM10  39.0  35.0  45.0
# 165  2020-06-24  PM2.5  19.0  16.0  19.0
# 166  2020-06-23  PM2.5  24.0  17.0  27.0
# 167  2020-06-22  PM2.5  22.0  17.0  24.0

# %%
df = df.sort_values(["기간"])
df
# Out:
#              기간   측정항목    서울    인천    경기
# 137  2020-06-22   PM10  39.0  35.0  45.0
# 167  2020-06-22  PM2.5  22.0  17.0  24.0
# 136  2020-06-23   PM10  42.0  33.0  50.0
# 166  2020-06-23  PM2.5  24.0  17.0  27.0
# 135  2020-06-24   PM10  28.0  27.0  31.0
# 165  2020-06-24  PM2.5  19.0  16.0  19.0

# %%
df = df.set_index('측정항목')
df
# Out:
#                기간    서울    인천    경기
# 측정항목
# PM10   2020-06-22  39.0  35.0  45.0
# PM2.5  2020-06-22  22.0  17.0  24.0
# PM10   2020-06-23  42.0  33.0  50.0
# PM2.5  2020-06-23  24.0  17.0  27.0
# PM10   2020-06-24  28.0  27.0  31.0
# PM2.5  2020-06-24  19.0  16.0  19.0

# %%
# %matplotlib inline

# 시각화 사전 준비
sns.set_context("talk")
sns.set_style("white")

# 한글 사용 준비
plt.rcParams['font.family']='NanumGothic'
plt.rcParams['axes.unicode_minus'] = False

# %%
fig, ax = plt.subplots(ncols=3, figsize=(20, 9))
ax = df[["서울", "경기","인천"]].plot.bar(ax=ax)

ax[0] = sns.countplot(x="서울", data=df)

species_u = penguins["species"].unique()

# plot 0 : matplotlib
for i, s in enumerate(species_u):
    ax[0].scatter(penguins["bill_length_mm"].loc[penguins["species"]==s],
                   penguins["bill_depth_mm"].loc[penguins["species"]==s],
                   c=f"C{i}", label=s, alpha=0.3
                  )
ax[0].legend(species_u, title="species")
ax[0].set_xlabel("Bill Length (mm)")
ax[0].set_ylabel("Bill Depth (mm)")

# plot 1 : seaborn
sns.scatterplot("bill_length_mm", "bill_depth_mm", hue="species", data=penguins, alpha=0.3, ax=axes[1])
ax[1].set_xlabel("Bill Length (mm)")
ax[1].set_ylabel("Bill Depth (mm)")

fig.tight_layout()

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")
tips = sns.load_dataset("tips")
ax = sns.barplot(x="day", y="total_bill", data=tips)

# %%
ax = sns.barplot(x="측정항목", y="total_bill", data=tips)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
fig, ax = plt.subplots(figsize=(20, 9))
 
ax = df[["서울", "경기","인천"]].plot.bar(ax=ax)
# Out:
# C:\Users\170729\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 52769 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\170729\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51221 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\170729\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 54637 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\170729\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 47785 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\170729\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 49436 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
ax = sns.barplot(x="측정항목", data=df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-9df61d8116b8> in <module>
# ----> 1 ax = sns.barplot(x="측정항목", data=df)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3167 ):
#    3168
# -> 3169     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    3170                           estimator, ci, n_boot, units, seed,
#    3171                           orient, color, palette, saturation,
#
# ...

# %%
df2 = pd.read_csv("data/ddddd.csv")
df2
# Out:
#     지역   측정항목          기간  농도
# 0   서울   PM10  2020-06-22  39
# 1   서울  PM2.5  2020-06-22  22
# 2   경기   PM10  2020-06-22  45
# 3   경기  PM2.5  2020-06-22  24
# 4   인천   PM10  2020-06-22  35
# 5   인천  PM2.5  2020-06-22  17
# 6   서울   PM10  2020-06-23  42
# 7   서울  PM2.5  2020-06-23  24
# 8   경기   PM10  2020-06-23  50
# 9   경기  PM2.5  2020-06-23  27
# 10  인천   PM10  2020-06-23  33
# 11  인천  PM2.5  2020-06-23  17
# 12  서울   PM10  2020-06-24  28
# 13  서울  PM2.5  2020-06-24  19
# 14  경기   PM10  2020-06-24  31
# 15  경기  PM2.5  2020-06-24  19
# 16  인천   PM10  2020-06-24  27
# 17  인천  PM2.5  2020-06-24  16

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")
tips = sns.load_dataset("tips")
ax = sns.barplot(x="day", y="total_bill", data=tips)

# %%
ax = sns.barplot(x="기간", y="농도", hue="측정항목", data=df2)

# %%
# 시각화 사전 준비
sns.set_context("talk")
sns.set_style("white")

# 한글 사용 준비
plt.rcParams['font.family']='NanumGothic'
plt.rcParams['axes.unicode_minus'] = False

# %%
# 시각화 사전 준비
sns.set_context("talk")
sns.set_style("white")

# 한글 사용 준비
plt.rcParams['font.family']='NanumGothic'
plt.rcParams['axes.unicode_minus'] = False
g = sns.catplot(x="측정항목", y="농도",
                hue="지역", col="기간",
                data=df2, kind="bar",
                height=4, aspect=.7);

# %%
# 시각화 사전 준비
sns.set_context("talk")
sns.set_style("white")

# 한글 사용 준비
plt.rcParams['font.family']='NanumGothic'
plt.rcParams['axes.unicode_minus'] = False

g = sns.catplot(x="측정항목", y="농도",
                hue="지역", col="기간",
                data=df2, kind="bar",
                height=4, aspect=.7);
(g.set_axis_labels("", "㎍/m³")
  .set_titles(""))

# %%
g = sns.catplot(x="측정항목", y="농도",
                hue="지역", col="기간",
                data=df2, kind="bar",
                height=4, aspect=.7);
(g.set_axis_labels("", "㎍/m³")
  .set_titles("")
  .despine(left=True))  
for index, row in groupedvalues.iterrows():
    g.text(row.name,row.tip, round(row.total_bill,2), color='black', ha="center")

# %%
import seaborn as sns
import numpy as np
sns.set(style="ticks",color_codes=True)
import matplotlib.pyplot as plt
#正常显示中文
plt.rcParams["font.sans-serif"]=["SimHei"]
 
#获取数据集
data = sns.load_dataset("tips")

#分组求和
grouped_values = data.groupby("day").sum().reset_index()
#设置绘制柱状图的颜色
pal = sns.color_palette("Greens_d",len(grouped_values))
rank = grouped_values["total_bill"].argsort().argsort()
g = sns.barplot(x="day",y="tip",data=grouped_values,palette=np.array(pal[::-1])[rank])
#在柱状图的上面显示各个类别的数量
for index,row in grouped_values.iterrows():
#在柱状图上绘制该类别的数量
    g.text(row.name,row.tip,round(row.total_bill,2),color="black",ha="center")

# %%
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df_seoul = pd.read_csv("data/seoul.csv")
df_gyeonggi = pd.read_csv("data/gg.csv")
df_incheon = pd.read_csv("data/ic.csv")

# %%
fig, axes = plt.subplots(ncols=3 figsize=(8, 4))

sns.scatterplot("측정항목", "농도", hue="지역", data=df_seoul, alpha=0.3, ax=axes[0])
sns.scatterplot("측정항목", "농도", hue="지역", data=df_gyeonggi, alpha=0.3, ax=axes[1])
sns.scatterplot("측정항목", "농도", hue="지역", data=df_seoul, alpha=0.3, ax=axes[2])
axes[0].set_xlabel("Bill Length (mm)")
axes[0].set_ylabel("Bill Depth (mm)")
axes[1].set_xlabel("Bill Length (mm)")
axes[1].set_ylabel("Bill Depth (mm)")
                  )
#axes[0].legend(species_u, title="species")


fig.tight_layout()

# %%
# 날짜별 데이터프레임
df_200622 = pd.read_csv("data/200622.csv")
df_200623 = pd.read_csv("data/200623.csv")
df_200624 = pd.read_csv("data/200624.csv")

# %%
# subplots 3개 만들기 (y축 공유 = 세로 동일)
fig, axes = plt.subplots(ncols=3, figsize=(20, 10), sharey=True)

# 날짜별(22일, 23일, 24일) 그래프 나누기
sns.barplot(x="측정항목", y="농도", hue="지역",
                data=df_200622, ax=axes[0]);
sns.barplot(x="측정항목", y="농도", hue="지역",
                data=df_200623, ax=axes[1]);
sns.barplot(x="측정항목", y="농도", hue="지역",
                data=df_200624, ax=axes[2]);

# x축 제목 변경
axes[0].set_xlabel("2020.06.22")
axes[1].set_xlabel("2020.06.23")
axes[2].set_xlabel("2020.06.24")

# y축 이름 변경
axes[0].set_ylabel("㎍/m³")
axes[1].set_ylabel("")
axes[2].set_ylabel("")

# 그래프가 들어있는 각 박스 위, 오른쪽 삭제?
sns.despine(bottom=False, left=False, ax=axes[0])
sns.despine(bottom=False, left=False, ax=axes[1])
sns.despine(bottom=False, left=False, ax=axes[2])

# 1번째, 3번째 범례 삭제 (hide legend)
axes[0].legend([],[], frameon=False)
axes[2].legend([],[], frameon=False)
